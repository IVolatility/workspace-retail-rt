# %%
import pandas as pd 
import ivolatility as ivol
import os

# Endpoint description: https://www.ivolatility.com/api/docs#tag/End-of-Day-(EOD)-Equities/operation/EOD%20Equities%20Info

ivolApiKey = os.getenv('API_KEY')
ivol.setLoginParams(apiKey=ivolApiKey)

getMarketData = ivol.setMethod('/equities/underlying-info')
marketData = getMarketData(date='2025-04-14',isActive='true',name='citi')
marketData
# Out:
#     Status Stock ticker                              Company name  \
# 0   Active          267                                 CITIC Ltd
# 1   Active         6030                                 CITIC SEC
# 2   Active          998                        CHINA CITIC BK -H-
# 3   Active         TRVC                       Citigroup Inc (EUR)
# 4   Active            C                             Citigroup Inc
# 5   Active      CCAC/WS  CITIC Capital Acquisition Corp (warrant)
# 6   Active          CFG              Citizens Financial Group Inc
# 7   Active          CIA                              Citizens Inc
# 8   Active         CIZN                  Citizens Holding Company
# 9   Active          CpN                             Citigroup Inc
# 10  Active         CTRN                           Citi Trends Inc
# 11  Active         CTXR                Citius Pharmaceuticals Inc
# 12  Active         CZNC                  Citizens & Northern Corp
# ...
